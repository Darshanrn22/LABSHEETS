# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.DataFrame({
    "x": np.random.randn(100),
    "y":np.random.randn(100),
    "values":np.random.randn(100)
})
cmap="magma"
alpha=1
plt.figure(figsize=(6,6))
plt.scatter(data["x"],data["y"],c=data["values"],cmap=cmap,alpha=alpha)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatterplot with Colormap")
plt.colorbar(label="value")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={"figure.figsize":(6,6)})

# %%
current_palette=sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("hls",8))

# %%
sns.palplot(sns.color_palette("husl",8))

# %%
sample_colors=["windows blue","amber","greyish","faded green","dusty purple","yellow","pale red"]
sns.palplot(sns.xkcd_palette(sample_colors))

# %%
sns.palplot(sns.color_palette("cubehelix",8))

# %%
sns.palplot(sns.cubehelix_palette(8))

# %% [markdown]
# Density plot

# %%
x,y =np.random.multivariate_normal([0,0],[[1,-.5],[-.5,1]],size=300).T
sample_cmap=sns.cubehelix_palette(light=1,as_cmap=True)
sns.kdeplot(x=x,y=y, cmap=sample_cmap, shade=True)
# Out:
# <ipython-input-22-fb4e22047617>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x,y=y, cmap=sample_cmap, shade=True)
# <Axes: >

# %%
sns.choose_cubehelix_palette(as_cmap=True)
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %%
sns.palplot(sns.cubehelix_palette(n_colors=8,start=1.7,rot=0.2))

# %%
sns.palplot(sns.cubehelix_palette(n_colors=8,start=1.7,rot=0.2,dark=0.3))

# %%
tips=sns.load_dataset("tips")
sns.stripplot(x="day",y="total_bill",data=tips,color="g")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')
sns.swarmplot(x="day",y="total_bill",data=tips,palette="viridis")
# Out:
# <ipython-input-28-5b3046365237>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=tips,palette="viridis")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')
sns.swarmplot(x="day",y="total_bill",data=tips,palette="magma")
# Out:
# <ipython-input-29-5e3baad18b28>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=tips,palette="magma")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')
sns.swarmplot(x="day",y="total_bill",data=tips,palette="inferno")
# Out:
# <ipython-input-30-d6655582ccec>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=tips,palette="inferno")
# <Axes: xlabel='day', ylabel='total_bill'>
